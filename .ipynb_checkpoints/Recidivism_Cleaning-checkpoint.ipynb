# %%
import pandas as pd

# %%
df = pd.read_csv("Resources/Recidivism.csv")

# %%
df.head()
# Out:
#    Fiscal Year Released  Recidivism Reporting Year      Race - Ethnicity  \
# 0                  2010                       2013  White - Non-Hispanic
# 1                  2010                       2013  White - Non-Hispanic
# 2                  2010                       2013  White - Non-Hispanic
# 3                  2010                       2013  White - Non-Hispanic
# 4                  2010                       2013  Black - Non-Hispanic
#
#   Age At Release  Convicting Offense Classification Convicting Offense Type  \
# 0        Under 25                          D Felony                 Violent
# 1    55 and Older                          D Felony            Public Order
# 2           25-34                          D Felony                Property
# 3    55 and Older                          C Felony                    Drug
# 4           25-34                          D Felony                    Drug
#
#   Convicting Offense Subtype Main Supervising District Release Type  \
# 0                    Assault                       4JD       Parole
# 1                        OWI                       7JD       Parole
# 2                   Burglary                       5JD       Parole
# 3                Trafficking                       8JD       Parole
# 4                Trafficking                       3JD       Parole
#
#   Release type: Paroled to Detainder united Part of Target Population  \
# 0                                    Parole                       Yes
# 1                                    Parole                       Yes
# 2                                    Parole                       Yes
# 3                                    Parole                       Yes
# 4                                    Parole                       Yes
#
#    Recidivism - Return to Prison numeric
# 0                                      1
# 1                                      1
# 2                                      1
# 3                                      1
# 4                                      1

# %%
df = df.drop(columns=['Recidivism Reporting Year', 'Convicting Offense Subtype', 'Main Supervising District', 'Release type: Paroled to Detainder united', 'Part of Target Population'], axis=1)
df.head()
# Out:
#    Fiscal Year Released      Race - Ethnicity Age At Release   \
# 0                  2010  White - Non-Hispanic        Under 25
# 1                  2010  White - Non-Hispanic    55 and Older
# 2                  2010  White - Non-Hispanic           25-34
# 3                  2010  White - Non-Hispanic    55 and Older
# 4                  2010  Black - Non-Hispanic           25-34
#
#   Convicting Offense Classification Convicting Offense Type Release Type  \
# 0                          D Felony                 Violent       Parole
# 1                          D Felony            Public Order       Parole
# 2                          D Felony                Property       Parole
# 3                          C Felony                    Drug       Parole
# 4                          D Felony                    Drug       Parole
#
#    Recidivism - Return to Prison numeric
# 0                                      1
# 1                                      1
# 2                                      1
# 3                                      1
# 4                                      1

# %%
df.loc[(df["Race - Ethnicity"] == "White - Hispanic"), "Race - Ethnicity"] = "Hispanic"

# %%
df.loc[(df["Race - Ethnicity"] == "White - Non-Hispanic"), "Race - Ethnicity"] = "White"

# %%
df.loc[(df["Race - Ethnicity"] == "Black - Hispanic"), "Race - Ethnicity"] = "Hispanic"

# %%
df.loc[(df["Race - Ethnicity"] == "Black - Non-Hispanic"), "Race - Ethnicity"] = "Black"

# %%
df.loc[(df["Race - Ethnicity"] == "Asian or Pacific Islander - Hispanic"), "Race - Ethnicity"] = "Hispanic"

# %%
df.loc[(df["Race - Ethnicity"] == "Asian or Pacific Islander - Non-Hispanic"), "Race - Ethnicity"] = "Asian"

# %%
df.loc[(df["Race - Ethnicity"] == "American Indian or Alaska Native - Hispanic"), "Race - Ethnicity"] = "Hispanic"

# %%
df.loc[(df["Race - Ethnicity"] == "American Indian or Alaska Native - Non-Hispanic"), "Race - Ethnicity"] = "Native"

# %%
df.loc[(df["Race - Ethnicity"] == "White -"), "Race - Ethnicity"] = "White"

# %%
df.loc[(df["Race - Ethnicity"] == "Black -"), "Race - Ethnicity"] = "Black"

# %%
df.loc[(df["Race - Ethnicity"] == "N/A -"), "Race - Ethnicity"] = "Other"

# %%
df.loc[(df["Race - Ethnicity"] == ""), "Race - Ethnicity"] = "Other"
df
# Out:
#        Fiscal Year Released Race - Ethnicity Age At Release   \
# 0                      2010            White        Under 25
# 1                      2010            White    55 and Older
# 2                      2010            White           25-34
# 3                      2010            White    55 and Older
# 4                      2010            Black           25-34
# ...                     ...              ...             ...
# 26015                  2015         Hispanic           25-34
# 26016                  2015            White           25-34
# 26017                  2015            Black        Under 25
# 26018                  2015            White        Under 25
# 26019                  2015            White           35-44
#
#       Convicting Offense Classification Convicting Offense Type  \
# 0                              D Felony                 Violent
# 1                              D Felony            Public Order
# 2                              D Felony                Property
# 3                              C Felony                    Drug
# 4                              D Felony                    Drug
# ...                                 ...                     ...
# 26015                          C Felony                 Violent
# 26016                          D Felony                Property
# 26017            Aggravated Misdemeanor                 Violent
# 26018                          D Felony                    Drug
# 26019                          C Felony                 Violent
#
#                              Release Type  \
# 0                                  Parole
# 1                                  Parole
# 2                                  Parole
# 3                                  Parole
# 4                                  Parole
# ...                                   ...
# 26015          Discharged End of Sentence
# 26016  Paroled to Detainer - Out of State
# 26017          Discharged End of Sentence
# 26018                              Parole
# 26019                              Parole
#
#        Recidivism - Return to Prison numeric
# 0                                          1
# 1                                          1
# 2                                          1
# 3                                          1
# 4                                          1
# ...                                      ...
# 26015                                      0
# 26016                                      0
# 26017                                      0
# 26018                                      0
# 26019                                      0
#
# [26020 rows x 7 columns]

# %%
df["Race - Ethnicity"].nunique()
# Out:
# 6
